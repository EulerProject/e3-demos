# %%
use tap demo_birds
# Out:
# Tap: demo_birds

# %%
is consistent
# Out:
# No

# %%
graph inconsistency
# Out:
# Take a look at the produced graph.

# %%
graph full inconsistency
# Out:
# Take a look at the produced graph.

# %%
graph reduced inconsistency
# Out:
# Take a look at the produced graph.
