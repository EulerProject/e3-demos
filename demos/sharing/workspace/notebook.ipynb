# %%
use tap demo_butterflies
# Out:
# Tap: demo_butterflies (Note: 1997 has multiple roots (2))

# %%
graph worlds
# Out:
# 1 worlds have been produced.

# %%
remove articulation 3
# Out:
# Tap: relaxed_swartz (Note: 1997 has multiple roots (2))

# %%
graph worlds
# Out:
# 5 worlds have been produced.

# %%
set config workspaceGitRepo = http://github.com/EulerProject/e3-demos.git
# Out:
# Configuration updated: workspaceGitRepo = http://github.com/EulerProject/e3-demos.git

# %%
git credentials github.com rodenhausen "my_secret_password"
# Out:
# git credentials set successfully

# %%
git push demos/sharing/workspace/e3_data
# Out:
# Pushed successfully

# %%
clear
# Out:
# Clear successful
# Tap: empty_tap (Invalid tap: underspecified)

# %%
git pull demos/sharing/workspace/e3_data
# Out:
# Pulled successfully
